# %%
# install requirements
# !pip install git+https://github.com/facebookresearch/segment-anything.git
# !pip install torch torchvision opencv-python numpy
# Out:
# Collecting git+https://github.com/facebookresearch/segment-anything.git
#   Cloning https://github.com/facebookresearch/segment-anything.git to c:\users\joaqu\appdata\local\temp\pip-req-build-sgpck00u
#   Resolved https://github.com/facebookresearch/segment-anything.git to commit 6fdee8f2727f4506cfbbe553e23b895e27956588
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Using legacy 'setup.py install' for segment-anything, since package 'wheel' is not installed.
# Installing collected packages: segment-anything
#   Running setup.py install for segment-anything: started
#   Running setup.py install for segment-anything: finished with status 'done'
# Successfully installed segment-anything-1.0
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/segment-anything.git 'C:\Users\joaqu\AppData\Local\Temp\pip-req-build-sgpck00u'
#
# [notice] A new release of pip available: 22.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting torch
#   Using cached torch-2.1.2-cp310-cp310-win_amd64.whl (192.3 MB)
# Collecting torchvision
#   Using cached torchvision-0.16.2-cp310-cp310-win_amd64.whl (1.1 MB)
# Collecting opencv-python
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
# Collecting numpy
#   Using cached numpy-1.26.3-cp310-cp310-win_amd64.whl (15.8 MB)
# Collecting jinja2
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting fsspec
#   Using cached fsspec-2023.12.2-py3-none-any.whl (168 kB)
# Collecting sympy
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting networkx
#   Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Collecting typing-extensions
#   Using cached typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Collecting filelock
#   Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# Collecting requests
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting pillow!=8.3.*,>=5.3.0
#   Using cached pillow-10.2.0-cp310-cp310-win_amd64.whl (2.6 MB)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.1.3-cp310-cp310-win_amd64.whl (17 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.1.0-py3-none-any.whl (104 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2023.11.17-py3-none-any.whl (162 kB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl (100 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.6-py3-none-any.whl (61 kB)
# Collecting mpmath>=0.19
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, urllib3, typing-extensions, sympy, pillow, numpy, networkx, MarkupSafe, idna, fsspec, filelock, charset-normalizer, certifi, requests, opencv-python, jinja2, torch, torchvision
# Successfully installed MarkupSafe-2.1.3 certifi-2023.11.17 charset-normalizer-3.3.2 filelock-3.13.1 fsspec-2023.12.2 idna-3.6 jinja2-3.1.2 mpmath-1.3.0 networkx-3.2.1 numpy-1.26.3 opencv-python-4.9.0.80 pillow-10.2.0 requests-2.31.0 sympy-1.12 torch-2.1.2 torchvision-0.16.2 typing-extensions-4.9.0 urllib3-2.1.0
# [notice] A new release of pip available: 22.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# wrap it up as a function
import base64
import os

from segment_anything import SamPredictor, sam_model_registry
import cv2
import numpy as np

# %%
model_path = 'sam_vit_b_01ec64.pth'

if not os.path.exists(model_path):
    url = 'https://dl.fbaipublicfiles.com/segment_anything/sam_vit_b_01ec64.pth'
    os.system(f'curl -O {url}')

# %%
sam = sam_model_registry["vit_b"](checkpoint=model_path)
predictor = SamPredictor(sam)

# %%
def remove_background(image_base64_encoding, x, y):

  image_bytes = base64.b64decode(image_base64_encoding)

  image = cv2.imdecode(np.frombuffer(image_bytes, dtype=np.uint8), cv2.IMREAD_COLOR)

  predictor.set_image(image)

  masks, scores, logits = predictor.predict(
                                    point_coords=np.asarray([[x, y]]),
                                    point_labels=np.asarray([1]),
                                    multimask_output=True
                                )

  C, H, W = masks.shape

  result_mask = np.zeros((H, W), dtype=bool)

  for j in range(C):
    result_mask |= masks[j, :, :]

  result_mask = result_mask.astype(np.uint8)

  alpha_channel = np.ones(result_mask.shape, dtype=result_mask.dtype) * 255

  alpha_channel[result_mask == 0] = 0

  result_image = cv2.merge((image, alpha_channel))

  _, result_image_bytes = cv2.imencode('.png', result_image)

  result_image_bytes = result_image_bytes.tobytes()

  result_image_bytes_encoded_base64 = base64.b64encode(result_image_bytes).decode('utf-8')

  return result_image_bytes_encoded_base64

# %%
import cv2
import matplotlib.pyplot as plt


image_path = 'test.jpg'
if not os.path.exists(image_path):
    url = 'https://utils-computervisiondeveloper.s3.amazonaws.com/media/public/test.jpg'
    os.system(f'curl -O {url}')

x = 329
y = 221

image = cv2.imread(image_path)

_, image_bytes = cv2.imencode('.png', image)

image_bytes = image_bytes.tobytes()

image_bytes_encoded_base64 = base64.b64encode(image_bytes).decode('utf-8')

result_image = remove_background(image_bytes_encoded_base64, x, y)

result_image_bytes = base64.b64decode(result_image)

result_image = cv2.imdecode(np.frombuffer(result_image_bytes, dtype=np.uint8), cv2.IMREAD_UNCHANGED)

plt.imshow(cv2.cvtColor(result_image, cv2.COLOR_BGRA2RGBA))
plt.show()

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.8.2-cp310-cp310-win_amd64.whl (7.6 MB)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\joaqu\jupyter\backgroundremoval\bgremoval\lib\site-packages (from matplotlib) (1.26.3)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.5-cp310-cp310-win_amd64.whl (56 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\joaqu\jupyter\backgroundremoval\bgremoval\lib\site-packages (from matplotlib) (23.2)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Requirement already satisfied: pillow>=8 in c:\users\joaqu\jupyter\backgroundremoval\bgremoval\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\joaqu\jupyter\backgroundremoval\bgremoval\lib\site-packages (from matplotlib) (2.8.2)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.2.0-cp310-cp310-win_amd64.whl (186 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.47.0-cp310-cp310-win_amd64.whl (2.2 MB)
# Requirement already satisfied: six>=1.5 in c:\users\joaqu\jupyter\backgroundremoval\bgremoval\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.47.0 kiwisolver-1.4.5 matplotlib-3.8.2 pyparsing-3.1.1
# [notice] A new release of pip available: 22.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install modelbit
# Out:
# Collecting modelbit
#   Downloading modelbit-0.31.8-py3-none-any.whl (114 kB)
#      -------------------------------------- 114.1/114.1 kB 6.5 MB/s eta 0:00:00
# Collecting texttable
#   Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: requests in c:\users\joaqu\jupyter\backgroundremoval\bgremoval\lib\site-packages (from modelbit) (2.31.0)
# Collecting importlib-metadata
#   Downloading importlib_metadata-7.0.1-py3-none-any.whl (23 kB)
# Collecting build
#   Downloading build-1.0.3-py3-none-any.whl (18 kB)
# Collecting pyyaml
#   Using cached PyYAML-6.0.1-cp310-cp310-win_amd64.whl (145 kB)
# Collecting build
#   Downloading build-0.10.0-py3-none-any.whl (17 kB)
# Collecting tqdm
#   Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Requirement already satisfied: jinja2 in c:\users\joaqu\jupyter\backgroundremoval\bgremoval\lib\site-packages (from modelbit) (3.1.2)
# Collecting zstandard
#   Downloading zstandard-0.22.0-cp310-cp310-win_amd64.whl (511 kB)
#      -------------------------------------- 511.6/511.6 kB 4.6 MB/s eta 0:00:00
# Collecting types-PyYAML
#   Downloading types_PyYAML-6.0.12.12-py3-none-any.whl (14 kB)
# Collecting pycryptodomex
#   Downloading pycryptodomex-3.19.1-cp35-abi3-win_amd64.whl (1.8 MB)
#      ---------------------------------------- 1.8/1.8 MB 9.3 MB/s eta 0:00:00
# Collecting pkginfo
#   Downloading pkginfo-1.9.6-py3-none-any.whl (30 kB)
# Collecting boto3>=1.23.0
#   Downloading boto3-1.34.12-py3-none-any.whl (139 kB)
#      -------------------------------------- 139.3/139.3 kB 4.2 MB/s eta 0:00:00
# Collecting types-pkg-resources
#   Downloading types_pkg_resources-0.1.3-py2.py3-none-any.whl (4.8 kB)
# Collecting urllib3<2,>=1.21.1
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      -------------------------------------- 143.8/143.8 kB 8.3 MB/s eta 0:00:00
# Collecting types-requests
#   Downloading types_requests-2.31.0.20231231-py3-none-any.whl (14 kB)
# Collecting pandas
#   Using cached pandas-2.1.4-cp310-cp310-win_amd64.whl (10.7 MB)
# Collecting appdirs
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.11.0,>=0.10.0
#   Downloading s3transfer-0.10.0-py3-none-any.whl (82 kB)
#      ---------------------------------------- 82.1/82.1 kB 4.5 MB/s eta 0:00:00
# Collecting botocore<1.35.0,>=1.34.12
#   Downloading botocore-1.34.12-py3-none-any.whl (11.9 MB)
#      ---------------------------------------- 11.9/11.9 MB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=19.0 in c:\users\joaqu\jupyter\backgroundremoval\bgremoval\lib\site-packages (from build->modelbit) (23.2)
# Collecting pyproject_hooks
#   Downloading pyproject_hooks-1.0.0-py3-none-any.whl (9.3 kB)
# Collecting tomli>=1.1.0
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: colorama in c:\users\joaqu\jupyter\backgroundremoval\bgremoval\lib\site-packages (from build->modelbit) (0.4.6)
# Collecting zipp>=0.5
#   Using cached zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\joaqu\jupyter\backgroundremoval\bgremoval\lib\site-packages (from jinja2->modelbit) (2.1.3)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\joaqu\jupyter\backgroundremoval\bgremoval\lib\site-packages (from pandas->modelbit) (1.26.3)
# Collecting pytz>=2020.1
#   Using cached pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\joaqu\jupyter\backgroundremoval\bgremoval\lib\site-packages (from pandas->modelbit) (2.8.2)
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.4-py2.py3-none-any.whl (346 kB)
#      ------------------------------------- 346.6/346.6 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joaqu\jupyter\backgroundremoval\bgremoval\lib\site-packages (from requests->modelbit) (2023.11.17)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joaqu\jupyter\backgroundremoval\bgremoval\lib\site-packages (from requests->modelbit) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\joaqu\jupyter\backgroundremoval\bgremoval\lib\site-packages (from requests->modelbit) (3.3.2)
# Collecting types-requests
#   Downloading types_requests-2.31.0.10-py3-none-any.whl (14 kB)
#   Downloading types_requests-2.31.0.9-py3-none-any.whl (14 kB)
#   Downloading types_requests-2.31.0.8-py3-none-any.whl (14 kB)
#   Downloading types_requests-2.31.0.7-py3-none-any.whl (14 kB)
#   Downloading types_requests-2.31.0.6-py3-none-any.whl (14 kB)
# Collecting types-urllib3
#   Downloading types_urllib3-1.26.25.14-py3-none-any.whl (15 kB)
# Requirement already satisfied: six>=1.5 in c:\users\joaqu\jupyter\backgroundremoval\bgremoval\lib\site-packages (from python-dateutil>=2.8.2->pandas->modelbit) (1.16.0)
# Installing collected packages: types-urllib3, types-PyYAML, types-pkg-resources, texttable, pytz, appdirs, zstandard, zipp, urllib3, tzdata, types-requests, tqdm, tomli, pyyaml, pycryptodomex, pkginfo, jmespath, pyproject_hooks, pandas, importlib-metadata, botocore, s3transfer, build, boto3, modelbit
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.1.0
#     Uninstalling urllib3-2.1.0:
#       Successfully uninstalled urllib3-2.1.0
# Successfully installed appdirs-1.4.4 boto3-1.34.12 botocore-1.34.12 build-0.10.0 importlib-metadata-7.0.1 jmespath-1.0.1 modelbit-0.31.8 pandas-2.1.4 pkginfo-1.9.6 pycryptodomex-3.19.1 pyproject_hooks-1.0.0 pytz-2023.3.post1 pyyaml-6.0.1 s3transfer-0.10.0 texttable-1.7.0 tomli-2.0.1 tqdm-4.66.1 types-PyYAML-6.0.12.12 types-pkg-resources-0.1.3 types-requests-2.31.0.6 types-urllib3-1.26.25.14 tzdata-2023.4 urllib3-1.26.18 zipp-3.17.0 zstandard-0.22.0
# [notice] A new release of pip available: 22.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import modelbit
mb = modelbit.login()
# Out:
# <div style="margin: 0; padding: 5px; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">
#   <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">
#     You're <span style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; color: #15803d; font-weight: bold;">connected</span> to Modelbit as je74@students.uwf.edu.
#     Workspace: <span style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; font-weight: bold; color: #845B99;">students-uwf</span>.
#
#       Region: <span style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; font-weight: bold; color: #845B99;">us-east-1</span>
#
#     Branch: <span style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; font-weight: bold; color: #845B99;">main</span>
# 	</div>
#
#
#
# </div>

# %%
mb.deploy(remove_background, python_packages=["git+https://github.com/facebookresearch/segment-anything.git"])
# Out:
# <div style="margin: 0; padding: 5px; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">
#   <div>
#     <span style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; font-weight: bold; color: #15803d;">Deploying </span> <span style="margin: 0; padding: 3px; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; font-weight: 400; background-color: rgba(209, 213, 219, 0.2);">remove_background</span>
#   </div>
#
#
#   <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">Uploading dependencies...</div>
# </div>
# Uploading 'predictor': 100%|████████████████████████████████████████████████████████| 352M/352M [01:52<00:00, 3.12MB/s]
# <div style="margin: 0; padding: 5px; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">
#   <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; font-weight: bold; color: #15803d;">Success!</div>
#
#     <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">
#       Deployment <span style="margin: 0; padding: 3px; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; font-weight: 400; background-color: rgba(209, 213, 219, 0.2);">remove_background</span>
#       will be ready in  a couple minutes.
#     </div>
#
#
#   <a href="https://us-east-1.modelbit.com/w/students-uwf/main/deployments/remove_background/apis" target="_blank" style="display: inline-block; margin-top: 12px;" >
#     <div
#       style="display: inline-block; background-color: #845B99; border-radius: 0.375rem; color: white; cursor: pointer; font-size: 14px; font-weight: 700; padding: 8px 16px;"
#       onmouseenter="this.style.background='#714488'"
#       onmouseleave="this.style.background='#845B99'"
#     >
#       View in Modelbit
#     </div>
#   </a>
# </div>

# %%
import cv2
import matplotlib.pyplot as plt
import requests


api_endpoint = "https://students-uwf.us-east-1.modelbit.com/v1/remove_background/latest"


image_path = 'test.jpg'
if not os.path.exists(image_path):
    url = 'https://utils-computervisiondeveloper.s3.amazonaws.com/media/public/test.jpg'
    os.system(f'curl -O {url}')

x = 329
y = 221

image = cv2.imread(image_path)

_, image_bytes = cv2.imencode('.png', image)

image_bytes = image_bytes.tobytes()

image_bytes_encoded_base64 = base64.b64encode(image_bytes).decode('utf-8')

api_data = {"data": [image_bytes_encoded_base64, x, y]}
response = requests.post(api_endpoint, json=api_data)
#print(response.json())

result_image = response.json()['data']

result_image_bytes = base64.b64decode(result_image)

result_image = cv2.imdecode(np.frombuffer(result_image_bytes, dtype=np.uint8), cv2.IMREAD_UNCHANGED)

plt.imshow(cv2.cvtColor(result_image, cv2.COLOR_BGRA2RGBA))
plt.show()
